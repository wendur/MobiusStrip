# %% [markdown]
# # Matplotlib

# %% [markdown]
# **Библиотека matplotlib** - это бибилиотека двумерной графики для языка программирования python с помощью которой можно создавать высококачественные рисунки различных форматов. Matplotlib представляет собой модуль-пакет для python.

# %% [markdown]
# ## Электронные ресурсы:

# %% [markdown]
# * [Краткое описания использования matplotlib](http://matplotlib.org/faq/usage_faq.html)
# * [Обучающие материалы по pyplot](http://matplotlib.org/users/pyplot_tutorial.html)
# * [Описание возможностей pyplot](http://matplotlib.org/api/pyplot_summary.html)
# * [Описание элементов рисунка (artists) в matplotlib для продвинутых пользователей](http://matplotlib.org/users/artists.html)

# %% [markdown]
# ## Основы

# %% [markdown]
# Каждая функция совершает различные изменения с изображением, например:
# - создаёт изображение
# - создаёт область построения на изображении
# - рисует линии в области построения
# - добавляет подписи
# - и т.д.
#
# При этом `matplotlib.pyplot` отслеживает состояние текущего изображения, и области построения, так что отрисовывающие функции применяются к текущим осям.

# %%
import matplotlib.pyplot as plt
#задаем значения по оси X и по оси Y
plt.plot([1,2,3,4], [1,4,9,16])
#добавляем подписи к осям
plt.ylabel('значение по оси Y')
plt.xlabel('значение по оси X')
plt.show()

# %% [markdown]
# **`plot()`** - универсальная команда и в неё можно передавать произвольное количество аргументов.
# Для каждой пары аргументов XY, существует необязательный третий аргумент, строка форматирования, которая определяет цвет и тип линии. Для того чтобы отобразить данные из предыдущего примера красными кружками, нужно ввести:

# %%
import matplotlib.pyplot as plt
#Полный список стилей можно найти в документации https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
#axis([xmin, xmax, ymin, ymax]) - устанавливает минимальные и максимальные границы осей. 
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# # Свойства линии

# %% [markdown]
# У линий есть множество атрибутов которые вы можете установить:
# - толщина
# - стиль
# - антиалиасинг (сглаживание)
# - и так далее.
#
# Для подробностей - [документация](https://matplotlib.org/api/artist_api.html#matplotlib.lines.Line2D.)
#
# Eсть несколько способов установить свойства линии:

# %%
#использовать ключевые слова, то есть вы пишете свойство и присваиваете ему значение:
plt.plot([1,2,3,4], [1,4,9,16], linewidth=7.0, color='b')
plt.show()

# %%
#использовать команду setp(). setp работает как со списком объектов, так и с одиночным объектом.
lines = plt.plot([1,2,3,4], [1,4,9,16])
# используем ключевые слова
plt.setp(lines, color='r', linewidth=7.0)
plt.show()

# %% [markdown]
# # Работа с несколькими окнами и осями

# %% [markdown]
# **`pyplot`**используют концепцию активного окна и активных осей. Все команды отрисовки чего бы то ни было применяются к именно к активным осям.
#
# Функция **`gca()`** возвращает активные оси (экземпляр класса matplotlib.axes.Axes)
#
# **`gcf()`** возвращает активное окно (figure) (экземпляр класса matplotlib.figure.Figure)
#
# Ниже представлен скрипт для создания двух графиков на одном изображении:

# %%
import matplotlib.pyplot as plt
import math

xs = []
sin_vals = []
cos_vals = []

x = 0.0
while x < 10.0:
    sin_vals += [ math.sin(x) ]
    cos_vals += [ math.cos(x) ]
    xs += [x]
    x += 0.1

plt.subplot(2,1,1)
plt.plot(xs, cos_vals, 'k')

plt.subplot(2,1,2)
plt.plot(xs, sin_vals, 'r--')
plt.show()

# %% [markdown]
# Команда **`subplot()`** определяет на какое количество подокон будет разбито ваше окно, и в какое из них будет происходить ваш вывод. При этом в качестве аргументов она принимает количество строк (numrows), количество колонок (numcols) и номер подокна(fignum), который изменяется от 1 до numrows*numcols (subplot(numrows,numcols,fignum)).
#
# Если numrows*numcols < 10 то запятые ставить не обязательно, то есть subplot(211) и subplot(2,1,1) идентичны друг другу. Вы можете создать сколько угодно подокон и осей.

# %% [markdown]
# Так же есть возможность рисовать несколько графиков в одном окне:

# %%
import matplotlib.pyplot as plt
import math

xs = []
sin_vals = []
cos_vals = []

x = 0.0
while x < 10.0:
    sin_vals += [ math.sin(x) ]
    cos_vals += [ math.cos(x) ]
    xs += [x]
    x += 0.1

plt.subplot(211)
#Рисуем два графика в одном окне (x1,y1,style1,x2,y2,style2)
plt.plot(xs, cos_vals, 'k', xs, sin_vals, 'r--')
plt.show()

# %% [markdown]
# Если вы хотите расположить оси (подокна) вручную, например не на прямоугольной сетке, а как-нибудь ёлочкой, используйте команду axes(), которая позволяет определить положение осей как axes([left, bottom, width, height]), где все значения изменяются от 0 до 1. Выглядеть это может так:

# %%
import matplotlib.pyplot as plt
import math

xs = []
sin_vals = []
cos_vals = []

x = 0.0
while x < 10.0:
    sin_vals += [ math.sin(x) ]
    cos_vals += [ math.cos(x) ]
    xs += [x]
    x += 0.1

plt.axes([0.6, 0.55, 0.4, 0.4])
plt.plot(xs, cos_vals, 'k')

plt.axes([0.3, 0.3, 0.4, 0.4])
plt.plot(xs, sin_vals, 'r--')
plt.show()

# %% [markdown]
# Вы можете создать несколько окон, вызывая **`figure()`** с увеличивающимся номером окна.

# %%
import matplotlib.pyplot as plt

#Первое окно
plt.figure(1)                
plt.subplot(211)             
plt.plot([1,2,3])
plt.subplot(212)             
plt.plot([4,5,6])

#Второе окно
plt.figure(2)                
plt.plot([4,5,6])
plt.show()

# %% [markdown]
# Чтобы сохранить получившийся рисунок нужно воспользоваться методом **`plt.savefig()`**. Он сохраняет текущую конфигурацию текущего рисунка в графический файл с некоторым расширением (png, jpeg, pdf и др.), который можно задать через параметр `fmt`. Поэтому её нужно вызывать в конце исходного кода, после всех вызова всех других команд. Если в python-скрипте создать несколько рисунков `figure` и попытаться сохранить их одной командой **`plt.savefig()`**, то будет сохранён последний рисунок `figure`.

# %%
import matplotlib.pyplot as plt
import math

xs = []
sin_vals = []
cos_vals = []

x = 0.0
while x < 10.0:
    sin_vals += [ math.sin(x) ]
    cos_vals += [ math.cos(x) ]
    xs += [x]
    x += 0.1

plt.subplot(211)
plt.plot(xs, cos_vals, 'k', xs, sin_vals, 'r--')
plt.grid(True)   # линии вспомогательной сетки
plt.savefig('image', fmt='png') #сохраняем
plt.show()

# %% [markdown]
# # Графические команды

# %% [markdown]
# В **Matplotlib** заложены как простые графические команды, так и достаточно сложные. Доступ к ним через **pyplot** означает использование синтаксиса вида `plt.название_команды()`.

# %% [markdown]
# [**Полный список команд**](https://matplotlib.org/api/pyplot_summary.html), доступный для pyplot, можно узнать на официальном сайте Matplotlib. Наиболее распространённые команды для создания научной графики в **matplotlib** это:

# %% [markdown]
# ## Самые простые графические команды

# %% [markdown]
# * `plt.scatter()` - маркер или точечное рисование
# * `plt.plot()` - ломаная линия
# * `plt.text()` - нанесение текста

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
# Добавление на рисунок прямоугольной (по умолчанию) области рисования
plt.scatter(0.0, 1.0)
plt.plot([-1.0, 1.0], [0.0, 1.0])
plt.text(0.5, 0.5, 'Text on figure')
plt.grid(True)   # линии вспомогательной сетки
plt.show()

# %% [markdown]
# ## Диаграммы

# %% [markdown]
# * `plt.bar()`, `plt.barh()`, `plt.barbs()`, `broken_barh()` - столбчатая диаграмма;
# * `plt.hist()`, `plt.hist2d()`, `plt.hlines` - гистограмма;
# * `plt.pie()` - круговая диаграмма;
# * `plt.boxplot()` - "ящик с усами" (boxwhisker);
# * `plt.errorbar()` - оценка погрешности, "усы".

# %% [markdown]
# Если бы matplotlib мог работать только со списками, то был бы довольно бесполезен для обработки данных. Как правило вы будете использовать матрицы **`numpy`**. Фактически внутри matplotlib все данные переводятся в матрицы **`numpy`**.

# %%
import matplotlib.pyplot as plt
import numpy as np

s = ['one','two','three ','four' ,'five']
x = [1, 2, 3, 4, 5]
z = np.random.random(100) # создаем рандомный вектор длинны 100
z1 = [10, 17, 24, 16, 22]
z2 = [12, 14, 21, 13, 17]

# bar()
fig = plt.figure()
plt.bar(x, z1)
plt.title('Simple bar chart')
plt.grid(True)   # линии вспомогательной сетки

# hist()
fig = plt.figure()
plt.hist(z)
plt.title('Simple histogramm')
plt.grid(True)

# pie()
fig = plt.figure()
plt.pie(x, labels=s)
plt.title('Simple pie chart')

# boxplot()
fig = plt.figure()
plt.boxplot([z1, z2])
plt.title('Simple box whisker chart')
plt.grid(True)

# errorbar()
fig = plt.figure()
plt.errorbar(x, z1, xerr=1, yerr=0.5)
plt.title('Simple error bar chart')
plt.grid(True)

plt.show()

# %% [markdown]
# ## Методы отображений

# %% [markdown]
# * `plt.pcolor()`, `plt.pcolormesh()` - псевдоцветное изображение матрицы (2D массива);
# * `plt.imshow()` - вставка графики (пиксели + сглаживание);

# %%
import matplotlib.pyplot as plt
import numpy as np

dat = np.random.random(1600).reshape(40,40) # создаём матрицу значений
fig = plt.figure()
pc = plt.pcolor(dat) # метод псевдографики pcolor
plt.colorbar(pc)
plt.title('Simple pcolor plot')

fig = plt.figure()
me = plt.imshow(dat) 
plt.colorbar(me)
plt.title('Simple imshow plot')

plt.show()

# %% [markdown]
# * `plt.contour()` - изолинии;
# * `plt.contourf()` - изолинии с послойной окраской;
# * `plt.matshow()` - отображение данных в виде квадратов.

# %%
import matplotlib.pyplot as plt
import numpy as np

dat = np.random.random(1600).reshape(40,40) # создаём матрицу значений

fig = plt.figure()
cr = plt.contour(dat) 
plt.colorbar(cr)
plt.title('Simple contour plot')

fig = plt.figure()
cf = plt.contourf(dat) 
plt.colorbar(cf)
plt.title('Simple contourf plot')

fig = plt.figure()
cf = plt.matshow(dat) 
plt.colorbar(cf, shrink=0.7)
plt.title('Simple matshow plot')

plt.show()

# %% [markdown]
# ## Методы заливки

# %% [markdown]
# * `plt.fill()` - заливка многоугольника;
# * `plt.fill_between()`, `plt.fill_betweenx()` - заливка между двумя линиями;

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 4*np.pi+0.1, 0.1)
y = np.sin(x)
z = np.sin(2*x)

x2 = np.arange(20)
y2 = -1.5*x2 + 2.33
z2 = 0.7*x2 - 8.5 

# fill()
fig = plt.figure()
plt.fill(x, y, 'r') # метод псевдографики pcolor
plt.title('Simple fill')
plt.grid(True)

# fill_between()
fig = plt.figure()
plt.plot(x2, z2, color='pink', linewidth=4.0)
plt.plot(x2, y2, color='g', linewidth=4.0)
plt.fill_between(x2, y2, z2) 
plt.title('Simple fill_between')
plt.grid(True)

# fill_betweenx()
fig = plt.figure()
plt.plot(z, x, color='pink', linewidth=4.0)
plt.plot(z, x-1.0, color='g', linewidth=4.0)
plt.fill_betweenx(z, x, x-1.0, color='cyan')
plt.title('Simple fill_betweenx')
plt.grid(True)

plt.show()

# %% [markdown]
# ## Векторные диаграммы

# %% [markdown]
# * `plt.streamplot()` - линии тока;
# * `plt.quiver()` - векторное поле.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-2*np.pi, 2*np.pi, 0.1)
u = np.sin(x)*np.cos(x)
v = np.cos(x)
uu, vv = np.meshgrid(u,v)

N = 100
x1 = np.random.random(N).reshape((10, 10))
y1 = np.random.random(N).reshape((10, 10))

# streamplot()
fig = plt.figure()
plt.streamplot(x, x, uu, vv) 
plt.title('Simple stream plot')
plt.grid(True)

# quiver()
fig = plt.figure()
plt.quiver(x1, y1, color='green') 
plt.title('Simple quiver plot')
plt.grid(True)

plt.show()

# %% [markdown]
# # Трехмерные графики matplotlib

# %% [markdown]
# Пакетом,  предназначенным  для  работы с  трехмерными  графиками, является  `mpl_toolkits.mplot3d`.
# В  основном  нам  будут  требоваться  объекты  и функции из его подмодуля `Axes3D`.

# %% [markdown]
# Чтобы трехмерные  графики  можно  было  свободно  вращать  мышкой, такие  графики следует строить в графическом окне matplotlib, а не отображать их в документе. Для этого потребуется выполнить магическую команду `%matplotlib qt`

# %%
#%matplotlib qt
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10,8)) # создаем пустое графическое окно размером 10 на 8
ax = Axes3D(fig) # создаемв нем трехмерныеоси
plt.show()

# %% [markdown]
# ## Трехмерная кривая

# %% [markdown]
# строится   с   помощью   функции
# `Axes3D.plot(x,y,z[,...])`,  которая  принимает  вектора   `x,y,z` координат узлов ломаной. При большом количестве узлов ломаная неотличима от кривой.

# %%
#%matplotlib qt
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
t = np.linspace(-4*np.pi,4*np.pi,100)
r = t**2/80+1
x = r*np.cos(t)# праметрическое уравнение кривой
y = r*np.sin(t)
z = t/(2*np.pi)
ax.plot(x,y,z,linewidth=4)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.show()

# %% [markdown]
# Задание  свойств  кривой  и  параметров  оформления  трехмерного  графика
# аналогичны  двумерным графикам.

# %% [markdown]
# ## График поверхности

# %% [markdown]
# строится с помощью функции `Axes3D.plot_surface(X,Y,Z,rstride=1,cstride=1[,...])`, где `X,Y,Z` двумерные  массивы,  содержащие `x,y,z` координаты  узлов многогранной поверхности, а параметры `rstride=1` и `cstride=1` определяют шаг по индексам `(row и column)` этих массивов. Единицы означают выбор всех значений  в  двумерных  массивах `X,Y,Z`. При  большом  размере матриц многогранная поверхность неотличима от криволинейной.

# %%
#%matplotlib qt
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
u = np.linspace(-4*np.pi,4*np.pi,100)
x,y = np.meshgrid(u,u)
r = np.sqrt(x**2+y**2)
z = np.sin(r)/r
surf = ax.plot_surface(x,y,z,rstride=1,cstride=1,linewidth=0,cmap = mpl.cm.hsv)
fig.colorbar(surf, shrink=0.75, aspect=15)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.show()

# %% [markdown]
# ## Каркасная поверхность

# %% [markdown]
# строится с помощью функции `Axes3D.plot_wireframe(X,Y,Z,rstride=1,cstride=1[,...])`,где `X,Y,Z` двумерные  массивы,  содержащие `x,y,z` координаты  узлов многогранной поверхности, а параметры `rstride=1` и `cstride=1` определяют шаг по индексам этих массивов.

# %%
#%matplotlib qt
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
u = np.linspace(-4*np.pi,4*np.pi,50)
x,y = np.meshgrid(u,u)
r = np.sqrt(x**2+y**2)
z = np.sin(r)/r
ax.plot_wireframe(x, y, z, rstride=1, cstride=1)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.show()

# %% [markdown]
# Есть возможность рисовать несколько графиков в одной системе

# %%
#%matplotlib qt
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def randrange(n, vmin, vmax):
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = Axes3D(fig)
u = np.linspace(-4*np.pi,4*np.pi,20)
x,y = np.meshgrid(u,u)
r = np.sqrt(x**2+y**2)
z = np.sin(r)/r
ax.plot_wireframe(x, y, z, rstride=1, cstride=1)

n = 100
for c, m, zl, zh in [('r', 'o', -11, -5), ('b', '^', -3, -5)]:
    xs = randrange(n, 10, 3)
    ys = randrange(n, 0, 10)
    zs = randrange(n, zl, zh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.show()
